# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
from astropy.io import fits
import scipy.fftpack

# %%
SOURCE_FOLDER='/mnt/home/bburkhart/ceph/www_data/CATS/MHD/machine_learning/b.1p.1/'
TARGET_FOLDER='/mnt/home/dheurtel/ceph/01_data'
PROJ_AXIS=0

# %%
os.listdir('/mnt/home/dheurtel/ceph/01_data')
# Out:
# ['CMB_PS_DIAG_H_ombh2', 'CATS_MHD_OrthBPROJ_DENSITY', 'CATS_MHD_BPROJ_DENSITY']

# %%
os.mkdir(os.path.join(TARGET_FOLDER,'CATS_MHD_BPROJ_DENSITY'))

# %%
os.mkdir(os.path.join(TARGET_FOLDER,'CATS_MHD_OrthBPROJ_DENSITY'))

# %%
os.mkdir(os.path.join(TARGET_FOLDER,'CATS_I'))

# %%
os.listdir(TARGET_FOLDER)
# Out:
# ['CMB_PS_DIAG_H_ombh2',
#  'CATS_I',
#  'CATS_MHD_OrthBPROJ_DENSITY',
#  'CATS_MHD_BPROJ_DENSITY']

# %%
def walker(prefix,folder):
    res_path_list=[]
    walker=os.walk(folder)
    for path, _ , files in walker:
        for name in files:
            if name.startswith(prefix):
                res_path_list.append(os.path.join(path,name))
    res_path_list.sort()
    return res_path_list

# %%
def fits_to_np(filepath):
    fits_obj=fits.open(filepath)
    np_data=fits_obj[0].data
    return np_data

# %% [markdown]
# **Examples & Pictures**

# %%
w=walker('dens',SOURCE_FOLDER)
head_np_list=[]
for i in range(991):
    head_np_list.append(np.sum(fits_to_np(w[i]), axis=0))
    if i%100==0:
        print(w[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /mnt/home/dheurtel/astroddpm/notebooks/data_processing.ipynb Cell 11 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2Bworkergpu054/mnt/home/dheurtel/astroddpm/notebooks/data_processing.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> head_np_list=[]
#       <a href='vscode-notebook-cell://ssh-remote%2Bworkergpu054/mnt/home/dheurtel/astroddpm/notebooks/data_processing.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> for i in range(991):
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bworkergpu054/mnt/home/dheurtel/astroddpm/notebooks/data_processing.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     head_np_list.append(np.sum(fits_to_np(w[i]), axis=0))
#       <a href='vscode-notebook-cell://ssh-remote%2Bworkergpu054/mnt/home/dheurtel/astroddpm/notebooks/data_processing.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     if i%100==0:
#       <a href='vscode-notebook-cell://ssh-remote%2Bworkergpu054/mnt/home/dheurtel/astroddpm/notebooks/data_processing.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>         print(w[i])
#
# IndexError: list index out of range

# %%
fig, ax =plt.subplots(2,5,figsize=(20, 8))

for i in range(10):
    ax[i//5,i%5].imshow(np.sum(head_np_list[i],axis=0))

# %%
for i in range(10):
    print(np.log(head_np_list[i]).mean(), np.log(head_np_list[i]).std())
# Out:
# 5.4877977 0.33586994
# 5.468566 0.3899917
# 5.486761 0.34357804
# 5.499386 0.30505642
# 5.5002046 0.3013668
# 5.497436 0.30592105
# 5.4971046 0.30492344
# 5.4862657 0.3437209
# 5.495538 0.31338882
# 5.4843473 0.35008118

# %%
np_tot_images = np.array(head_np_list)
np_tot_images.shape
# Out:
# (751, 256, 256)

# %%
STD, MEAN = np.log(np_tot_images).std(), np.log(np_tot_images).mean()

# %%
def path_list_to_np_list(path_list):
    return [fits_to_np(path) for path in path_list]

# %%
def np_transform(np_array):
    return ((np.log(np_array)-MEAN)/STD).astype(np.float32)

# %%
def np_to_npy(np_list,folder,prefix=None,file_name_list=None):
    if not(prefix==None):
        count=0
        for arr in np_list:
            np.save(os.path.join(folder,prefix+'_'+str(count).zfill(2)),arr)
            count+=1
    elif not(file_name_list==None):
        if len(np_list)==len(file_name_list):
            for i in range(len(np_list)):
                np.save(os.path.join(folder,file_name_list[i]),np_list[i])
        else:
            raise ValueError('Size of list of filenames not the same as size of list of np arrays to save')
    else:
        raise ValueError('Provide a way to name the files')

# %%
def parrallel_projection(np_list,axis=0):
    return [np.sum(arr, axis=axis) for arr in np_list]

# %%
def perpendicular_projections(np_list,axis_exclude=0):
    dims=list(range(np_list[0].ndim)).pop(axis_exclude)
    all_proj=[]
    for dim in dims:
        all_proj+=parrallel_projection(np_list,axis=dim)
    return all_proj

# %%
def efficient_walker(prefix,source_folder=SOURCE_FOLDER,target_folder=TARGET_FOLDER,_axis=0,n_dim=3):
    walker=os.walk(source_folder)
    dims=list(range(n_dim))
    dims.pop(_axis)
    count_fits=0
    count_parr=0
    count_orth=0
    for path, _ , files in walker:
        for name in files:
            if name.startswith(prefix):
                count_fits+=1
                np_data=fits.open(os.path.join(path,name))[0].data
                np_main_proj=np_transform(np.sum(np_data,axis=_axis))
                np.save(os.path.join(target_folder,'CATS_MHD_BPROJ_DENSITY','field_'+str(count_parr).zfill(4)),np_main_proj)
                count_parr+=1
                for d in dims:
                    np_other_proj=np_transform(np.sum(np_data,axis=d))
                    np.save(os.path.join(target_folder,'CATS_MHD_OrthBPROJ_DENSITY','field_'+str(count_orth).zfill(4)),np_other_proj)
                    count_orth+=1
    print('Explored source folder %s  for prefix %s \n Found %s files \n Saved %s projections of these files along axis %s and %s orthogonal to it \n Everything is saved in folder %s.'%(source_folder,prefix,count_fits,count_parr,_axis,count_orth,target_folder))

# %%
efficient_walker('dens')
# Out:
# Explored source folder /mnt/home/bburkhart/ceph/www_data/CATS/MHD/machine_learning/b.1p.1/  for prefix dens
#  Found 991 files
#  Saved 991 projections of these files along axis 0 and 1982 orthogonal to it
#  Everything is saved in folder /mnt/home/dheurtel/ceph/01_data.

# %% [markdown]
# *As we can see, we have periodic boundary conditions on all three dimensions*

# %% [markdown]
# ##### TOY DATASET

# %%
TOY_DATASET_DIR='/mnt/home/dheurtel/ceph/00_exploration_data/toy'

# %%
os.mkdir(TOY_DATASET_DIR)

# %%
mu,sigma=5.5,0.3

# %%
t=np.zeros((256,256))
for n in range(1000):
    centerx,centery=np.random.normal(128,30,2)
    radius=np.random.normal(60,5)
    for i in range(256):
        for j in range(256):
            t[i,j]=2.0 if ((i-centery)**2+(j-centerx)**2<=radius**2) else 1.0
    mode=np.random.randint(0,2)*2-1
    t*=mode*np.random.normal(1,0.3)
    t=t*sigma+mu
    t=np.exp(t)
    t=t.astype(np.float32)
    np.save(os.path.join(TOY_DATASET_DIR,'file_'+str(n).zfill(4)),t)

# %%
l=(os.listdir(TOY_DATASET_DIR))
tot=np.concatenate([np.load(os.path.join(TOY_DATASET_DIR,l[i])).reshape(1,1,256,256) for i in range(1000)])
pix=tot.flatten()
pix=(np.log(pix)-mu)/sigma

# %%
plt.hist(pix,density=True, histtype='step', bins=50)
plt.show()

# %%
plt.imshow(tot[11,0],vmin=-2,vmax=2)

# %% [markdown]
# **PLANCK NOISE**
#
# Separate real and imaginary part into a tensor of size (2, 256, 256) then normalize by mean (0) and standard deviation ($\approx$ 5e-5)

# %% [markdown]
# **Gaussian Field**

# %%
corr=np.zeros((257,257))
for i in range(257):
    for j in range(257):
        corr[i,j]=np.exp(-((i-128)**2+(j-128)**2)/100)
plt.imshow(corr)

# %%
seed=np.random.randn(257,257)
gp=np.fft.ifft2(np.sqrt((np.fft.fft2(np.fft.fftshift(corr))))*np.fft.fft2(seed))
fig, ax =plt.subplots(1,2,figsize=(20, 10))

ax[0].imshow(np.real(gp))
ax[1].imshow(np.imag(gp))

# %% [markdown]
# The imaginary part is 7 order of magnitude smaller than the real part. This comes from numerical errors and justifies taking the real part in most of our code blocks

# %%
def fftind(size):
    """ Returns a np array of shifted Fourier coordinates k_x k_y.     
        Input args:
            size (integer): The size of the coordinate array to create
        Returns:
            k_ind, np array of shape (2, size, size) with:
                k_ind[0,:,:]:  k_x components
                k_ind[1,:,:]:  k_y components
        """
    k_ind = np.mgrid[:size, :size] - int( (size + 1)/2 )
    k_ind = scipy.fftpack.fftshift(k_ind)
    return( k_ind )



def gaussian_random_field(alpha = 3.0,
                          size = 256, 
                          flag_normalize = True):
    """ Returns a np array of shifted Fourier coordinates k_x k_y. 
        Input args:
            alpha (double, default = 3.0): 
                The power of the power-law momentum distribution
            size (integer, default = 128):
                The size of the square output Gaussian Random Fields
            flag_normalize (boolean, default = True):
                Normalizes the Gaussian Field:
                    - to have an average of 0.0
                    - to have a standard deviation of 1.0
        Returns:
            gfield (np array of shape (size, size)):
                The random gaussian random field      
        Example:
        import matplotlib
        import matplotlib.pyplot as plt
        example = gaussian_random_field()
        plt.imshow(example)
        """
        
        # Defines momentum indices
    k_idx = fftind(size)

        # Defines the amplitude as a power law 1/|k|^(alpha/2)
    amplitude = np.power( k_idx[0]**2 + k_idx[1]**2 + 1e-10, -alpha/4.0 )
    amplitude[0,0] = 0
    
        # Draws a complex gaussian random noise with normal
        # (circular) distribution
    noise = np.random.normal(size = (size, size)) \
        + 1j * np.random.normal(size = (size, size))
    
        # To real space
    gfield = np.fft.ifft2(noise * amplitude).imag
    
        # Sets the standard deviation to one
    if flag_normalize:
        gfield = gfield - np.mean(gfield)
        gfield = gfield/np.std(gfield)
        
    return gfield

# %%
g=gaussian_random_field(4)

# %%
plt.imshow(g)

# %%
import numpy as np
import scipy.stats as stats


def compute_autocovariance(data):
    """
    Compute the autocovariance matrix of the input data.
    
    Works for any dimension.

    Parameters
    ----------
    data : array
        Input data.

    Returns
    -------
    array
        Autocovariance matrix.

    """
    return np.real(np.fft.ifftn(np.absolute(np.fft.fftn(data - data.mean())) ** 2) / np.prod(data.shape))

def generate_grf(cov, mean=0.0):
    """
    Generate a realization of a 2D real-valued GRF with periodic boundary conditions
    for a given mean and autocovariance matrix.

    Parameters
    ----------
    cov : array
        2D autocovariance matrix.
    mean : float, optional
        Mean value of the GRF. The default is 0.0.

    Raises
    ------
    Exception
        DESCRIPTION.

    Returns
    -------
    array
        Realization of the corresponding GRF.

    """
    if cov.ndim != 2:
        raise Exception("This function expects cov to be be a 2D array.")
    M, N = cov.shape
    gamma = np.fft.fft2(cov)
    Z = np.random.randn(M, N) + 1j * np.random.randn(M, N)
    X = np.fft.fft2(np.multiply(np.sqrt(gamma), Z / np.sqrt(M * N))).real
    return X + mean

# %%
SOURCE_DIR='/mnt/home/dheurtel/ceph/00_exploration_data/density/b_proj/'

# %%
dataset=MHDProjDataset(SOURCE_DIR,test_batch_length=0,random_rotate=True,transforms=LogNormalTransform())

# %%
cov_mean=np.zeros((256,256))

# %%
n=len(dataset)
n
# Out:
# 991

# %%
for data_point in dataset:
    cov_mean+=compute_autocovariance(data_point)/n

# %%
plt.imshow(np.fft.fftshift(cov_mean))

# %%
im=generate_grf(cov_mean)

# %%
plt.imshow(im)

# %%
grf_test=[generate_grf(cov_mean) for i in range(1000)]

# %%
cov_mean_test=np.zeros((256,256))
for data_point in grf_test:
    cov_mean_test+=compute_autocovariance(data_point)/1000

# %%
np.linalg.norm(cov_mean_test-cov_mean)/np.linalg.norm(cov_mean)
# Out:
# 0.030695085497971578

# %% [markdown]
# ### For our gaussian random field ddpm

# %%
power_spectrum = np.fft.fft2(cov_mean).real

# %%
POWER_SPECTRUM_FILE = '/mnt/home/dheurtel/ceph/00_exploration_data/power_spectra/same.npy'

# %%
np.save(POWER_SPECTRUM_FILE, power_spectrum)

# %%
from validationMetrics.powerSpectrum import power_spectrum_iso, plot_ps

# %%
bins = np.linspace(0, np.pi, 100)

# %%
a,b,c=power_spectrum_iso(im, bins=bins)

# %%
plot_ps(a, [b], show=True)

# %%
GRF_DATASET_DIR='/mnt/home/dheurtel/ceph/00_exploration_data/grf'

SUBDIR1='same'
SUBDIR2='power2'

# %%
os.mkdir(GRF_DATASET_DIR)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 os.mkdir(GRF_DATASET_DIR)
#
# FileExistsError: [Errno 17] File exists: '/mnt/home/dheurtel/ceph/00_exploration_data/grf'

# %%
os.mkdir(os.path.join(GRF_DATASET_DIR, SUBDIR1))
os.mkdir(os.path.join(GRF_DATASET_DIR, SUBDIR2))
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 os.mkdir(os.path.join(GRF_DATASET_DIR, SUBDIR1))
#       2 os.mkdir(os.path.join(GRF_DATASET_DIR, SUBDIR2))
#
# FileExistsError: [Errno 17] File exists: '/mnt/home/dheurtel/ceph/00_exploration_data/grf/same'

# %%
for n in range(1024):
    t = generate_grf(cov_mean)
    t=t.astype(np.float32)
    np.save(os.path.join(GRF_DATASET_DIR,SUBDIR1,'file_'+str(n).zfill(4)),t)

# %%
for n in range(1024):
    t = gaussian_random_field(4)
    t=t.astype(np.float32)
    np.save(os.path.join(GRF_DATASET_DIR,SUBDIR2,'file_'+str(n).zfill(4)),t)

# %%
dataset_same=MHDProjDataset(os.path.join(GRF_DATASET_DIR, SUBDIR2), None, random_rotate=True,test_batch_length=128)

# %%
power_spectra1=np.concatenate([power_spectrum_iso(data_point,bins=bins)[1].reshape(1,100) for data_point in dataset_same],axis=0)

# %%
bins_centers = (bins[:-1] + bins[1:])/2
    
fig, ax = plt.subplots(1, 1,figsize=(7,7), layout='constrained')
mean1,std1=np.mean(power_spectra1,axis=0)[:99],np.std(power_spectra1,axis=0)[:99]

ax.plot(bins_centers,mean1,'-k')
ax.fill_between(bins_centers,mean1+std1,mean1-std1)

ax.set_xscale('log')
ax.set_yscale('log')
fig.supylabel('Isotropic Power')
fig.supxlabel('Wavenumber')
# Out:
# Text(0.5, 0.01, 'Wavenumber')

# %%
SUBDIR3='gauss'

# %%
os.mkdir(os.path.join(GRF_DATASET_DIR, SUBDIR3))

# %%
for n in range(1024):
    t = np.random.randn(256,256)
    t=t.astype(np.float32)
    np.save(os.path.join(GRF_DATASET_DIR,SUBDIR3,'file_'+str(n).zfill(4)),t)

# %% [markdown]
# **Tools for physical transformations**

# %%
def QiU_to_EiB(data):
    """Convert Q+iU maps to E+iB maps.
    cf Kamionkowski, Kovetz 2015

    Parameters
    ----------
    data : array_like
        Q+iU maps. The two last dimensions are the spatial dimensions.

    Returns
    -------
    array_like
        E+iB maps. The two last dimensions are the spatial dimensions.
    """
    M, N = data.shape[-2:]

    k2d_x, k2d_y = np.meshgrid(np.fft.fftfreq(M), np.fft.fftfreq(N), indexing='ij')
    phik = np.arctan2(k2d_y, k2d_x)

    data_QiUf = np.fft.fft2(data)

    return np.fft.ifft2(np.exp(-2j*phik)*data_QiUf) / np.sqrt(2)

def EiB_to_QiU(data):
    """Convert E+iB maps to Q+iU maps.
    cf Kamionkowski, Kovetz 2015

    Parameters
    ----------
    data : array_like
        E+iB maps. The two last dimensions are the spatial dimensions.

    Returns
    -------
    array_like
        Q+iU maps. The two last dimensions are the spatial dimensions.
    """
    M, N = data.shape[-2:]

    k2d_x, k2d_y = np.meshgrid(np.fft.fftfreq(M), np.fft.fftfreq(N), indexing='ij')

    phik = np.arctan2(k2d_y, k2d_x)

    data_Eibf = np.fft.fft2(data)

    return np.fft.ifft2(np.exp(2j*phik)*data_Eibf * np.sqrt(2))

# Constants
h = 6.62607015e-34  # in J.s
c = 299792458       # in m/s
k = 1.380649e-23    # in J/K

def planck_function(nu, T):
    return (2*h*nu**3 / c**2) * 1 / (np.exp(h*nu/(k*T)) - 1)

def mbb_emission(nu, T, beta, nu_0=353e9):
    return (nu/nu_0)**beta * planck_function(nu, T)

def build_Stokes(n, bx, by, bz, channels, proj="x", p0=0.1, T_vals=(15., 1.), beta_vals=(1.5, 0.2)):
    """_summary_

    Input cubes axes order must be [Z, Y, X].

    Parameters
    ----------
    n : _type_
        _description_
    bx : _type_
        _description_
    by : _type_
        _description_
    bz : _type_
        _description_
    channels : _type_
        In Hz.
    proj : str, optional
        _description_, by default "x"
    p0 : float, optional
        _description_, by default 0.1
    T_vals : tuple, optional
        Temperature mean and std, in K, by default (15., 1.)
    beta_vals : tuple, optional
        Spectral index mean and std, in, by default (1.5, 0.2)

    Returns
    -------
    _type_
        _description_

    Raises
    ------
    NotImplementedError
        _description_
    """
    N = n.shape[0]
    assert n.shape == (N, N, N) # Cubic box is assumed

    # Temperatures (K) and spectral indices for model
    T_mean = T_vals[0]
    T_std = T_vals[1]
    b_mean = beta_vals[0]
    b_std = beta_vals[1]

    # Model for temperature and spectral indices maps
    n_norm_ranks = stats.rankdata(n) / (1 + N**3)
    T_map = stats.norm.ppf(1 - n_norm_ranks, loc=T_mean, scale=T_std).reshape((N, N, N))
    b_map = stats.norm.ppf(n_norm_ranks, loc=b_mean, scale=b_std).reshape((N, N, N))

    # Magnetic part
    b_norm2 = (bx ** 2 + by ** 2 + bz ** 2)
    if proj == "x":
        projaxis = 2
        I_mag_part = (by**2 + bz**2) / b_norm2 - 2/3
        QiU_mag_part = (by + 1j * bz) ** 2 / b_norm2
    elif proj == "z":
        projaxis = 0
        I_mag_part = (bx**2 + by**2) / b_norm2 - 2/3
        QiU_mag_part = (bx + 1j * by) ** 2 / b_norm2
    else:
        raise NotImplementedError(f"proj={proj} invalid!")

    I_maps = np.zeros((len(channels), N, N), dtype=np.float32)
    QiU_maps = np.zeros((len(channels), N, N), dtype=np.complex64)

    # Projection
    for i, chan in enumerate(channels):
        # MBB map
        mbb = mbb_emission(chan, T_map, b_map, nu_0=353e9)

        I_maps[i] = np.mean(mbb * n * (1 - p0*I_mag_part), axis=projaxis)
        QiU_maps[i] = np.mean(mbb * n * QiU_mag_part, axis=projaxis)
    
    return I_maps, QiU_maps

# %%
l1 = os.listdir('/mnt/home/dheurtel/ceph/00_exploration_data/density/b_proj/')
l2 = os.listdir('/mnt/home/dheurtel/ceph/00_exploration_data/density/orth_b_proj/')

# %%
import torch
import astroddpm.analysis.validationMetrics.powerSpectrum as ps

# %%
### load a bunch of images of both l1 and l2 and then put them in two torch tensors
np_list_1 = [np.load(os.path.join('/mnt/home/dheurtel/ceph/00_exploration_data/density/b_proj/', l1[i])).reshape(1,1,256,256) for i in range(800)]
np_list_2 = [np.load(os.path.join('/mnt/home/dheurtel/ceph/00_exploration_data/density/orth_b_proj/', l2[i])).reshape(1,1,256,256) for i in range(800)]

np_vect_1 = np.concatenate(np_list_1, axis=0)
np_vect_2 = np.concatenate(np_list_2, axis=0)

tensor_1 = torch.from_numpy(np_vect_1)
tensor_2 = torch.from_numpy(np_vect_2)

# %%
ps.plot_sets_power_spectrum_iso2d([tensor_1, tensor_2])
# Out:
# ([tensor([7.1460e+11, 5.7216e+11, 2.0147e+11, 7.8205e+10, 3.6976e+10, 2.1630e+10,
#           1.3956e+10, 8.6796e+09, 6.0674e+09, 4.0733e+09, 2.8617e+09, 2.1723e+09,
#           1.6029e+09, 1.2023e+09, 9.1302e+08, 7.0208e+08, 5.5865e+08, 4.4748e+08,
#           1.0251e+07, 9.2114e+06, 7.8231e+06, 7.4358e+06, 6.6620e+06, 5.6806e+06,
#           5.2148e+06, 4.3815e+06, 4.0503e+06, 3.8222e+06, 3.4017e+06, 3.0075e+06,
#           2.6775e+06, 2.4097e+06, 2.1395e+06, 2.0398e+06, 1.7532e+06, 1.6719e+06,
#           1.5774e+06, 1.3543e+06, 1.2757e+06, 1.1824e+06, 1.0464e+06, 9.6844e+05,
#           8.8299e+05, 7.9877e+05, 7.2244e+05, 6.7940e+05, 6.1129e+05, 5.8438e+05,
#           5.2680e+05, 4.8779e+05, 4.5710e+05, 4.0357e+05, 3.7609e+05, 3.3361e+05,
#           3.2289e+05, 2.8923e+05, 2.6598e+05, 2.5449e+05, 2.3125e+05, 2.2369e+05,
#           1.9987e+05, 1.9665e+05, 1.8054e+05, 1.6417e+05, 1.5377e+05, 1.4624e+05,
#           1.3781e+05, 1.2516e+05, 1.2029e+05, 1.1851e+05, 1.1109e+05, 1.0472e+05,
#           1.0191e+05, 1.0058e+05, 9.4440e+04, 8.6593e+04, 8.4122e+04, 8.1421e+04,
#           7.7510e+04, 7.6254e+04, 7.5233e+04, 2.8822e+04], device='cuda:0')],
#  tensor([0.0159, 0.0476, 0.0793, 0.1111, 0.1428, 0.1745, 0.2063, 0.2380, 0.2697,
#          0.3015, 0.3332, 0.3649, 0.3967, 0.4284, 0.4601, 0.4919, 0.5236, 0.5553,
#          0.5871, 0.6188, 0.6505, 0.6823, 0.7140, 0.7457, 0.7775, 0.8092, 0.8409,
#          0.8727, 0.9044, 0.9361, 0.9679, 0.9996, 1.0313, 1.0631, 1.0948, 1.1265,
#          1.1583, 1.1900, 1.2217, 1.2535, 1.2852, 1.3169, 1.3487, 1.3804, 1.4121,
#          1.4439, 1.4756, 1.5073, 1.5391, 1.5708, 1.6025, 1.6343, 1.6660, 1.6977,
#          1.7295, 1.7612, 1.7929, 1.8247, 1.8564, 1.8881, 1.9199, 1.9516, 1.9833,
#          2.0151, 2.0468, 2.0785, 2.1103, 2.1420, 2.1737, 2.2055, 2.2372, 2.2689,
#          2.3007, 2.3324, 2.3641, 2.3959, 2.4276, 2.4593, 2.4911, 2.5228, 2.5545,
#          2.5863, 2.6180, 2.6497, 2.6815, 2.7132, 2.7449, 2.7767, 2.8084, 2.8401,
#          2.8719, 2.9036, 2.9353, 2.9671, 2.9988, 3.0305, 3.0623, 3.0940, 3.1257]),
#  None)

# %%
import astroddpm.analysis.validationMetrics.minkowskiFunctional as mf

# %%
l_1 = np.split(tensor_1.numpy(), len(tensor_1), axis=0)
l_1 = [l_1[i][0][0] for i in range(len(l_1))]

l_2 = np.split(tensor_2.numpy(), len(tensor_2), axis=0)
l_2 = [l_2[i][0][0] for i in range(len(l_2))]

range_min = 0

range_max = 700

# %%
smm, sms=mf.plot_mink_functionals([l_1,l_2],gs_vals = np.linspace(range_min, range_max, 200),
          names = ['1','2'], cols = ['b', 'r'], 
          savefig_dict={})

# %%
new_DESTINATION_FOLDER = '/mnt/home/dheurtel/ceph/01_data/CATS_I'

# %%
import shutil

# %%
count = 0
for filename in l1:
    shutil.copy(os.path.join('/mnt/home/dheurtel/ceph/00_exploration_data/density/b_proj/', filename), os.path.join(new_DESTINATION_FOLDER, 'file_{}.npy'.format(str(count).zfill(4))))
    count += 1

# %%
l=os.listdir(new_DESTINATION_FOLDER)
l.sort()
l
# Out:
# ['file_0000.npy',
#  'file_0001.npy',
#  'file_0002.npy',
#  'file_0003.npy',
#  'file_0004.npy',
#  'file_0005.npy',
#  'file_0006.npy',
#  'file_0007.npy',
#  'file_0008.npy',
#  'file_0009.npy',
#  'file_0010.npy',
#  'file_0011.npy',
#  'file_0012.npy',
#  'file_0013.npy',
#  'file_0014.npy',
#  'file_0015.npy',
#  'file_0016.npy',
#  'file_0017.npy',
#  'file_0018.npy',
#  'file_0019.npy',
#  'file_0020.npy',
#  'file_0021.npy',
#  'file_0022.npy',
#  'file_0023.npy',
#  'file_0024.npy',
#  'file_0025.npy',
#  'file_0026.npy',
#  'file_0027.npy',
#  'file_0028.npy',
#  'file_0029.npy',
#  'file_0030.npy',
#  'file_0031.npy',
#  'file_0032.npy',
#  'file_0033.npy',
#  'file_0034.npy',
#  'file_0035.npy',
#  'file_0036.npy',
#  'file_0037.npy',
#  'file_0038.npy',
#  'file_0039.npy',
#  'file_0040.npy',
#  'file_0041.npy',
#  'file_0042.npy',
#  'file_0043.npy',
#  'file_0044.npy',
#  'file_0045.npy',
#  'file_0046.npy',
#  'file_0047.npy',
#  'file_0048.npy',
#  'file_0049.npy',
#  'file_0050.npy',
#  'file_0051.npy',
#  'file_0052.npy',
#  'file_0053.npy',
#  'file_0054.npy',
#  'file_0055.npy',
#  'file_0056.npy',
#  'file_0057.npy',
#  'file_0058.npy',
#  'file_0059.npy',
#  'file_0060.npy',
#  'file_0061.npy',
#  'file_0062.npy',
#  'file_0063.npy',
#  'file_0064.npy',
#  'file_0065.npy',
#  'file_0066.npy',
#  'file_0067.npy',
#  'file_0068.npy',
#  'file_0069.npy',
#  'file_0070.npy',
#  'file_0071.npy',
#  'file_0072.npy',
#  'file_0073.npy',
#  'file_0074.npy',
#  'file_0075.npy',
#  'file_0076.npy',
#  'file_0077.npy',
#  'file_0078.npy',
#  'file_0079.npy',
#  'file_0080.npy',
#  'file_0081.npy',
#  'file_0082.npy',
#  'file_0083.npy',
#  'file_0084.npy',
#  'file_0085.npy',
#  'file_0086.npy',
#  'file_0087.npy',
#  'file_0088.npy',
#  'file_0089.npy',
#  'file_0090.npy',
#  'file_0091.npy',
#  'file_0092.npy',
#  'file_0093.npy',
#  'file_0094.npy',
#  'file_0095.npy',
#  'file_0096.npy',
#  'file_0097.npy',
#  'file_0098.npy',
#  'file_0099.npy',
#  'file_0100.npy',
#  'file_0101.npy',
#  'file_0102.npy',
#  'file_0103.npy',
#  'file_0104.npy',
#  'file_0105.npy',
#  'file_0106.npy',
#  'file_0107.npy',
#  'file_0108.npy',
#  'file_0109.npy',
#  'file_0110.npy',
#  'file_0111.npy',
#  'file_0366.npy',
#  'file_0367.npy',
#  'file_0368.npy',
#  'file_0369.npy',
#  'file_0370.npy',
#  'file_0371.npy',
#  'file_0372.npy',
#  'file_0373.npy',
#  'file_0374.npy',
#  'file_0375.npy',
#  'file_0376.npy',
#  'file_0377.npy',
#  'file_0378.npy',
#  'file_0379.npy',
#  'file_0380.npy',
#  'file_0381.npy',
#  'file_0382.npy',
#  'file_0383.npy',
#  'file_0384.npy',
#  'file_0385.npy',
#  'file_0386.npy',
#  'file_0387.npy',
#  'file_0388.npy',
#  'file_0389.npy',
#  'file_0390.npy',
#  'file_0391.npy',
#  'file_0392.npy',
#  'file_0393.npy',
#  'file_0394.npy',
#  'file_0395.npy',
#  'file_0396.npy',
#  'file_0397.npy',
#  'file_0398.npy',
#  'file_0399.npy',
#  'file_0400.npy',
#  'file_0401.npy',
#  'file_0402.npy',
#  'file_0403.npy',
#  'file_0404.npy',
#  'file_0405.npy',
#  'file_0406.npy',
#  'file_0407.npy',
#  'file_0408.npy',
#  'file_0409.npy',
#  'file_0410.npy',
#  'file_0411.npy',
#  'file_0412.npy',
#  'file_0413.npy',
#  'file_0414.npy',
#  'file_0415.npy',
#  'file_0416.npy',
#  'file_0417.npy',
#  'file_0418.npy',
#  'file_0419.npy',
#  'file_0420.npy',
#  'file_0421.npy',
#  'file_0422.npy',
#  'file_0423.npy',
#  'file_0424.npy',
#  'file_0425.npy',
#  'file_0426.npy',
#  'file_0427.npy',
#  'file_0428.npy',
#  'file_0429.npy',
#  'file_0430.npy',
#  'file_0431.npy',
#  'file_0432.npy',
#  'file_0433.npy',
#  'file_0434.npy',
#  'file_0435.npy',
#  'file_0436.npy',
#  'file_0437.npy',
#  'file_0438.npy',
#  'file_0439.npy',
#  'file_0440.npy',
#  'file_0441.npy',
#  'file_0442.npy',
#  'file_0443.npy',
#  'file_0444.npy',
#  'file_0445.npy',
#  'file_0446.npy',
#  'file_0447.npy',
#  'file_0448.npy',
#  'file_0449.npy',
#  'file_0450.npy',
#  'file_0451.npy',
#  'file_0452.npy',
#  'file_0453.npy',
#  'file_0454.npy',
#  'file_0455.npy',
#  'file_0456.npy',
#  'file_0457.npy',
#  'file_0458.npy',
#  'file_0459.npy',
#  'file_0460.npy',
#  'file_0461.npy',
#  'file_0462.npy',
#  'file_0463.npy',
#  'file_0464.npy',
#  'file_0465.npy',
#  'file_0466.npy',
#  'file_0467.npy',
#  'file_0468.npy',
#  'file_0469.npy',
#  'file_0470.npy',
#  'file_0471.npy',
#  'file_0472.npy',
#  'file_0473.npy',
#  'file_0474.npy',
#  'file_0475.npy',
#  'file_0476.npy',
#  'file_0477.npy',
#  'file_0478.npy',
#  'file_0479.npy',
#  'file_0480.npy',
#  'file_0481.npy',
#  'file_0482.npy',
#  'file_0483.npy',
#  'file_0484.npy',
#  'file_0485.npy',
#  'file_0486.npy',
#  'file_0487.npy',
#  'file_0488.npy',
#  'file_0489.npy',
#  'file_0490.npy',
#  'file_0491.npy',
#  'file_0492.npy',
#  'file_0493.npy',
#  'file_0494.npy',
#  'file_0495.npy',
#  'file_0496.npy',
#  'file_0497.npy',
#  'file_0498.npy',
#  'file_0499.npy',
#  'file_0500.npy',
#  'file_0501.npy',
#  'file_0502.npy',
#  'file_0503.npy',
#  'file_0504.npy',
#  'file_0505.npy',
#  'file_0506.npy',
#  'file_0507.npy',
#  'file_0508.npy',
#  'file_0509.npy',
#  'file_0510.npy',
#  'file_0511.npy',
#  'file_0512.npy',
#  'file_0513.npy',
#  'file_0514.npy',
#  'file_0515.npy',
#  'file_0516.npy',
#  'file_0517.npy',
#  'file_0518.npy',
#  'file_0519.npy',
#  'file_0520.npy',
#  'file_0521.npy',
#  'file_0522.npy',
#  'file_0523.npy',
#  'file_0524.npy',
#  'file_0525.npy',
#  'file_0526.npy',
#  'file_0527.npy',
#  'file_0528.npy',
#  'file_0529.npy',
#  'file_0530.npy',
#  'file_0531.npy',
#  'file_0532.npy',
#  'file_0533.npy',
#  'file_0534.npy',
#  'file_0535.npy',
#  'file_0536.npy',
#  'file_0537.npy',
#  'file_0538.npy',
#  'file_0539.npy',
#  'file_0540.npy',
#  'file_0541.npy',
#  'file_0542.npy',
#  'file_0543.npy',
#  'file_0544.npy',
#  'file_0545.npy',
#  'file_0546.npy',
#  'file_0547.npy',
#  'file_0548.npy',
#  'file_0549.npy',
#  'file_0550.npy',
#  'file_0551.npy',
#  'file_0552.npy',
#  'file_0553.npy',
#  'file_0554.npy',
#  'file_0555.npy',
#  'file_0556.npy',
#  'file_0557.npy',
#  'file_0558.npy',
#  'file_0559.npy',
#  'file_0560.npy',
#  'file_0561.npy',
#  'file_0562.npy',
#  'file_0563.npy',
#  'file_0564.npy',
#  'file_0565.npy',
#  'file_0566.npy',
#  'file_0567.npy',
#  'file_0568.npy',
#  'file_0569.npy',
#  'file_0570.npy',
#  'file_0571.npy',
#  'file_0572.npy',
#  'file_0573.npy',
#  'file_0574.npy',
#  'file_0575.npy',
#  'file_0576.npy',
#  'file_0577.npy',
#  'file_0578.npy',
#  'file_0579.npy',
#  'file_0580.npy',
#  'file_0581.npy',
#  'file_0582.npy',
#  'file_0583.npy',
#  'file_0584.npy',
#  'file_0585.npy',
#  'file_0586.npy',
#  'file_0587.npy',
#  'file_0588.npy',
#  'file_0589.npy',
#  'file_0590.npy',
#  'file_0591.npy',
#  'file_0592.npy',
#  'file_0593.npy',
#  'file_0594.npy',
#  'file_0595.npy',
#  'file_0596.npy',
#  'file_0597.npy',
#  'file_0598.npy',
#  'file_0599.npy',
#  'file_0600.npy',
#  'file_0601.npy',
#  'file_0602.npy',
#  'file_0603.npy',
#  'file_0604.npy',
#  'file_0605.npy',
#  'file_0606.npy',
#  'file_0607.npy',
#  'file_0608.npy',
#  'file_0609.npy',
#  'file_0610.npy',
#  'file_0611.npy',
#  'file_0612.npy',
#  'file_0613.npy',
#  'file_0614.npy',
#  'file_0615.npy',
#  'file_0616.npy',
#  'file_0617.npy',
#  'file_0618.npy',
#  'file_0619.npy',
#  'file_0620.npy',
#  'file_0621.npy',
#  'file_0622.npy',
#  'file_0623.npy',
#  'file_0624.npy',
#  'file_0625.npy',
#  'file_0626.npy',
#  'file_0627.npy',
#  'file_0628.npy',
#  'file_0629.npy',
#  'file_0630.npy',
#  'file_0631.npy',
#  'file_0632.npy',
#  'file_0633.npy',
#  'file_0634.npy',
#  'file_0635.npy',
#  'file_0636.npy',
#  'file_0637.npy',
#  'file_0638.npy',
#  'file_0639.npy',
#  'file_0640.npy',
#  'file_0641.npy',
#  'file_0642.npy',
#  'file_0643.npy',
#  'file_0644.npy',
#  'file_0645.npy',
#  'file_0646.npy',
#  'file_0647.npy',
#  'file_0648.npy',
#  'file_0649.npy',
#  'file_0650.npy',
#  'file_0651.npy',
#  'file_0652.npy',
#  'file_0653.npy',
#  'file_0654.npy',
#  'file_0655.npy',
#  'file_0656.npy',
#  'file_0657.npy',
#  'file_0658.npy',
#  'file_0659.npy',
#  'file_0660.npy',
#  'file_0661.npy',
#  'file_0662.npy',
#  'file_0663.npy',
#  'file_0664.npy',
#  'file_0665.npy',
#  'file_0666.npy',
#  'file_0667.npy',
#  'file_0668.npy',
#  'file_0669.npy',
#  'file_0670.npy',
#  'file_0671.npy',
#  'file_0672.npy',
#  'file_0673.npy',
#  'file_0674.npy',
#  'file_0675.npy',
#  'file_0676.npy',
#  'file_0677.npy',
#  'file_0678.npy',
#  'file_0679.npy',
#  'file_0680.npy',
#  'file_0681.npy',
#  'file_0682.npy',
#  'file_0683.npy',
#  'file_0684.npy',
#  'file_0685.npy',
#  'file_0686.npy',
#  'file_0687.npy',
#  'file_0688.npy',
#  'file_0689.npy',
#  'file_0690.npy',
#  'file_0691.npy',
#  'file_0692.npy',
#  'file_0693.npy',
#  'file_0694.npy',
#  'file_0695.npy',
#  'file_0696.npy',
#  'file_0697.npy',
#  'file_0698.npy',
#  'file_0699.npy',
#  'file_0700.npy',
#  'file_0701.npy',
#  'file_0702.npy',
#  'file_0703.npy',
#  'file_0704.npy',
#  'file_0705.npy',
#  'file_0706.npy',
#  'file_0707.npy',
#  'file_0708.npy',
#  'file_0709.npy',
#  'file_0710.npy',
#  'file_0711.npy',
#  'file_0712.npy',
#  'file_0713.npy',
#  'file_0714.npy',
#  'file_0715.npy',
#  'file_0716.npy',
#  'file_0717.npy',
#  'file_0718.npy',
#  'file_0719.npy',
#  'file_0720.npy',
#  'file_0721.npy',
#  'file_0722.npy',
#  'file_0723.npy',
#  'file_0724.npy',
#  'file_0725.npy',
#  'file_0726.npy',
#  'file_0727.npy',
#  'file_0728.npy',
#  'file_0729.npy',
#  'file_0730.npy',
#  'file_0731.npy',
#  'file_0732.npy',
#  'file_0733.npy',
#  'file_0734.npy',
#  'file_0735.npy',
#  'file_0736.npy',
#  'file_0737.npy',
#  'file_0738.npy',
#  'file_0739.npy',
#  'file_0740.npy',
#  'file_0741.npy',
#  'file_0742.npy',
#  'file_0743.npy',
#  'file_0744.npy',
#  'file_0745.npy',
#  'file_0746.npy',
#  'file_0747.npy',
#  'file_0748.npy',
#  'file_0749.npy',
#  'file_0750.npy',
#  'file_0751.npy',
#  'file_0752.npy',
#  'file_0753.npy',
#  'file_0754.npy',
#  'file_0755.npy',
#  'file_0756.npy',
#  'file_0757.npy',
#  'file_0758.npy',
#  'file_0759.npy',
#  'file_0760.npy',
#  'file_0761.npy',
#  'file_0762.npy',
#  'file_0763.npy',
#  'file_0764.npy',
#  'file_0765.npy',
#  'file_0766.npy',
#  'file_0767.npy',
#  'file_0768.npy',
#  'file_0769.npy',
#  'file_0770.npy',
#  'file_0771.npy',
#  'file_0772.npy',
#  'file_0773.npy',
#  'file_0774.npy',
#  'file_0775.npy',
#  'file_0776.npy',
#  'file_0777.npy',
#  'file_0778.npy',
#  'file_0779.npy',
#  'file_0780.npy',
#  'file_0781.npy',
#  'file_0782.npy',
#  'file_0783.npy',
#  'file_0784.npy',
#  'file_0785.npy',
#  'file_0786.npy',
#  'file_0787.npy',
#  'file_0788.npy',
#  'file_0789.npy',
#  'file_0790.npy',
#  'file_0791.npy',
#  'file_0792.npy',
#  'file_0793.npy',
#  'file_0794.npy',
#  'file_0795.npy',
#  'file_0796.npy',
#  'file_0797.npy',
#  'file_0798.npy',
#  'file_0799.npy',
#  'file_0800.npy',
#  'file_0801.npy',
#  'file_0802.npy',
#  'file_0803.npy',
#  'file_0804.npy',
#  'file_0805.npy',
#  'file_0806.npy',
#  'file_0807.npy',
#  'file_0808.npy',
#  'file_0809.npy',
#  'file_0810.npy',
#  'file_0811.npy',
#  'file_0812.npy',
#  'file_0813.npy',
#  'file_0814.npy',
#  'file_0815.npy',
#  'file_0816.npy',
#  'file_0817.npy',
#  'file_0818.npy',
#  'file_0819.npy',
#  'file_0820.npy',
#  'file_0821.npy',
#  'file_0822.npy',
#  'file_0823.npy',
#  'file_0824.npy',
#  'file_0825.npy',
#  'file_0826.npy',
#  'file_0827.npy',
#  'file_0828.npy',
#  'file_0829.npy',
#  'file_0830.npy',
#  'file_0831.npy',
#  'file_0832.npy',
#  'file_0833.npy',
#  'file_0834.npy',
#  'file_0835.npy',
#  'file_0836.npy',
#  'file_0837.npy',
#  'file_0838.npy',
#  'file_0839.npy',
#  'file_0840.npy',
#  'file_0841.npy',
#  'file_0842.npy',
#  'file_0843.npy',
#  'file_0844.npy',
#  'file_0845.npy',
#  'file_0846.npy',
#  'file_0847.npy',
#  'file_0848.npy',
#  'file_0849.npy',
#  'file_0850.npy',
#  'file_0851.npy',
#  'file_0852.npy',
#  'file_0853.npy',
#  'file_0854.npy',
#  'file_0855.npy',
#  'file_0856.npy',
#  'file_0857.npy',
#  'file_0858.npy',
#  'file_0859.npy',
#  'file_0860.npy',
#  'file_0861.npy',
#  'file_0862.npy',
#  'file_0863.npy',
#  'file_0864.npy',
#  'file_0865.npy',
#  'file_0866.npy',
#  'file_0867.npy',
#  'file_0868.npy',
#  'file_0869.npy',
#  'file_0870.npy',
#  'file_0871.npy',
#  'file_0872.npy',
#  'file_0873.npy',
#  'file_0874.npy',
#  'file_0875.npy',
#  'file_0876.npy',
#  'file_0877.npy',
#  'file_0878.npy',
#  'file_0879.npy',
#  'file_0880.npy',
#  'file_0881.npy',
#  'file_0882.npy',
#  'file_0883.npy',
#  'file_0884.npy',
#  'file_0885.npy',
#  'file_0886.npy',
#  'file_0887.npy',
#  'file_0888.npy',
#  'file_0889.npy',
#  'file_0890.npy',
#  'file_0891.npy',
#  'file_0892.npy',
#  'file_0893.npy',
#  'file_0894.npy',
#  'file_0895.npy',
#  'file_0896.npy',
#  'file_0897.npy',
#  'file_0898.npy',
#  'file_0899.npy',
#  'file_0900.npy',
#  'file_0901.npy',
#  'file_0902.npy',
#  'file_0903.npy',
#  'file_0904.npy',
#  'file_0905.npy',
#  'file_0906.npy',
#  'file_0907.npy',
#  'file_0908.npy',
#  'file_0909.npy',
#  'file_0910.npy',
#  'file_0911.npy',
#  'file_0912.npy',
#  'file_0913.npy',
#  'file_0914.npy',
#  'file_0915.npy',
#  'file_0916.npy',
#  'file_0917.npy',
#  'file_0918.npy',
#  'file_0919.npy',
#  'file_0920.npy',
#  'file_0921.npy',
#  'file_0922.npy',
#  'file_0923.npy',
#  'file_0924.npy',
#  'file_0925.npy',
#  'file_0926.npy',
#  'file_0927.npy',
#  'file_0928.npy',
#  'file_0929.npy',
#  'file_0930.npy',
#  'file_0931.npy',
#  'file_0932.npy',
#  'file_0933.npy',
#  'file_0934.npy',
#  'file_0935.npy',
#  'file_0936.npy',
#  'file_0937.npy',
#  'file_0938.npy',
#  'file_0939.npy',
#  'file_0940.npy',
#  'file_0941.npy',
#  'file_0942.npy',
#  'file_0943.npy',
#  'file_0944.npy',
#  'file_0945.npy',
#  'file_0946.npy',
#  'file_0947.npy',
#  'file_0948.npy',
#  'file_0949.npy',
#  'file_0950.npy',
#  'file_0951.npy',
#  'file_0952.npy',
#  'file_0953.npy',
#  'file_0954.npy',
#  'file_0955.npy',
#  'file_0956.npy',
#  'file_0957.npy',
#  'file_0958.npy',
#  'file_0959.npy',
#  'file_0960.npy',
#  'file_0961.npy',
#  'file_0962.npy',
#  'file_0963.npy',
#  'file_0964.npy',
#  'file_0965.npy',
#  'file_0966.npy',
#  'file_0967.npy',
#  'file_0968.npy',
#  'file_0969.npy',
#  'file_0970.npy',
#  'file_0971.npy',
#  'file_0972.npy',
#  'file_0973.npy',
#  'file_0974.npy',
#  'file_0975.npy',
#  'file_0976.npy',
#  'file_0977.npy',
#  'file_0978.npy',
#  'file_0979.npy',
#  'file_0980.npy',
#  'file_0981.npy',
#  'file_0982.npy',
#  'file_0983.npy',
#  'file_0984.npy',
#  'file_0985.npy',
#  'file_0986.npy',
#  'file_0987.npy',
#  'file_0988.npy',
#  'file_0989.npy',
#  'file_0990.npy']

# %%
mean = 255.9088
std = 79.5066

# %%
for file in os.listdir(new_DESTINATION_FOLDER):
    img = np.load(os.path.join(new_DESTINATION_FOLDER, file))
    img = (img - mean) / std
    np.save(os.path.join(new_DESTINATION_FOLDER, file), img)
